# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import os
os.getcwd()
# Out:
# 'c:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\wikipedia-data'

# %%
os.chdir("c:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\wikipedia-data")

# %%
df = pd.read_csv("male_verb.csv",on_bad_lines='skip')

# %%
df.isna().sum()
# Out:
# year           0
# categorize1    0
# dtype: int64

# %%
words = " ".join(title for title in df.categorize1)
img = np.array(Image.open("C:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\image.png"))
wc = WordCloud(collocations = False, background_color ='black',mask=img).generate(words)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df2 = pd.read_csv("female_verb.csv",on_bad_lines='skip')

# %%
w1 = " ".join(title for title in df2.categorize1)
img = np.array(Image.open("C:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\image.png"))
wc = WordCloud(collocations = False, background_color ='black',mask=img).generate(w1)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
madj=pd.read_csv('male_adjectives.csv',on_bad_lines='skip')

# %%
w2 = " ".join(title for title in madj.categorize)
img = np.array(Image.open("C:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\image.png"))
wc = WordCloud(collocations = False, background_color ='black',mask=img).generate(w2)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
fadj=pd.read_csv('female_adjectives.csv',on_bad_lines='skip')

# %%
w3 = " ".join(title for title in fadj.categorize)
img = np.array(Image.open("C:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\image.png"))
wc = WordCloud(collocations = False, background_color ='black',mask=img).generate(w3)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
songDB = pd.read_csv("songsDB.csv",on_bad_lines='skip')

# %%
songDB.head()
# Out:
#        movieTitle_year      singer_name  gender  song_count
# 0    Aag Aur Daag_1970      Asha Bhosle  FEMALE           3
# 1    Aag Aur Daag_1970    Mohammed Rafi    MALE           1
# 2  Aan Milo Sajna_1970    Kishore Kumar    MALE           2
# 3  Aan Milo Sajna_1970  Lata Mangeshkar  FEMALE           3
# 4  Aan Milo Sajna_1970    Mohammed Rafi    MALE           2

# %%
songf = pd.read_csv("songsFrequency.csv",on_bad_lines='skip')
songf.head()
# Out:
#                          MOVIE NAME   YEAR   MALE SINGER COUNT  \
# 0                Raabta (film)_2017   2017                 5.0
# 1                 Luv U Soniyo_2013   2013                 4.0
# 2                     Sahibaan_1993   1993                 2.0
# 3  Baap Numbri Beta Dus Numbri_1990   1990                 1.0
# 4             Jyoti Bane Jwala_1980   1980                 3.0
#
#     FEMALE SINGER COUNT   MALE SONG COUNT   FEMALE SONG COUNT
# 0                   2.0               8.0                 2.0
# 1                   1.0               6.0                 1.0
# 2                   2.0               3.0                 6.0
# 3                   2.0               1.0                 4.0
# 4                   3.0               4.0                 5.0

# %%
for i, predictor in enumerate(songDB.drop(columns= ['movieTitle_year','singer_name'])):
  plt.figure(i)
  sns.countplot(data= songDB, x=predictor, hue= 'gender')
