# %% [markdown]
# Male and Female centrality plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import matplotlib.ticker as ticker

# %%
matplotlib.rcParams['font.size'] = 18
sns.set_context('talk', font_scale=1.2);

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\wikipedia-data'

# %%
os.chdir("c:\\Users\\harleyquinn\\Documents\\GitHub\\Bollywood_movie_analysis\\wikipedia-data")

# %%
fc = pd.read_csv('female_centrality.csv')
mc =pd.read_csv("male_centrality.csv")
fc.head()
# Out:
#        Movie Name Cast Name  Total Centrality  Average Centrality
# 0  Aan Milo Sajna     woman        222.500000           18.541667
# 1  Aan Milo Sajna   savitri        868.166667            6.627226
# 2  Aan Milo Sajna   deepali          0.000000            0.000000
# 3       Abhinetri    anjana        319.000000            4.037975
# 4   Aag Aur Shola      usha         48.000000            0.888889

# %%
fc.describe()
# Out:
#        Total Centrality  Average Centrality
# count       5043.000000         5043.000000
# mean         385.929784            4.955029
# std          882.565299            6.571231
# min            0.000000            0.000000
# 25%           38.000000            1.252358
# 50%          138.000000            3.129032
# 75%          390.750000            6.202941
# max        20080.269911           91.600980

# %%
mc.describe()
# Out:
#        Total Centrality  Average Centrality
# count       9348.000000         9348.000000
# mean         461.064942            4.810756
# std         2926.885729           18.233392
# min            0.000000            0.000000
# 25%           24.578571            0.783574
# 50%          136.000000            2.729289
# 75%          416.683333            5.683440
# max       260924.611430         1562.422823

# %%
sns.pairplot(fc);

# %%
sns.pairplot(mc);

# %%
matplotlib.rcParams['font.size'] = 10
sns.pairplot(fc, hue = 'Total Centrality');

# %%
matplotlib.rcParams['font.size'] = 10
sns.pairplot(mc, hue = 'Total Centrality');

# %%
fc['Total Centrality'].value_counts().head(5).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
mc['Total Centrality'].value_counts().head(5).plot(kind='barh',color="red", figsize=(10,5))
# Out:
# <AxesSubplot:>
